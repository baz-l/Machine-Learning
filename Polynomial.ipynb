# %% [markdown]
# <a href="https://colab.research.google.com/github/baz-l/Machine-Learning/blob/main/Polynomial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/polynomial.csv")
df
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
df.size
# Out:
# 18

# %%
df.shape
# Out:
# (6, 3)

# %%
df.columns
# Out:
# Index(['sno', 'Temperature', 'Pressure'], dtype='object')

# %%
df.head()
# Out:
#    sno  Temperature  Pressure
# 0    1            0    0.0002
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900

# %%
df.tail()
# Out:
#    sno  Temperature  Pressure
# 1    2           20    0.0012
# 2    3           40    0.0060
# 3    4           60    0.0300
# 4    5           80    0.0900
# 5    6          100    0.2700

# %%
x=df.iloc[:,:-1]
x
# Out:
#    sno  Temperature
# 0    1            0
# 1    2           20
# 2    3           40
# 3    4           60
# 4    5           80
# 5    6          100

# %%
y=df.iloc[:,-1]
y
# Out:
# 0    0.0002
# 1    0.0012
# 2    0.0060
# 3    0.0300
# 4    0.0900
# 5    0.2700
# Name: Pressure, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)
x_train
# Out:
#    sno  Temperature
# 4    5           80
# 0    1            0
# 3    4           60
# 5    6          100

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0.05259286, 0.00763571])

# %%
print(f"Slope is {model.coef_}")
# Out:
# Slope is [0.00011211 0.00224225]

# %%
print(f"Constant is {model.intercept_}")
# Out:
# Constant is -0.0374335411471321

# %%
from sklearn.metrics import mean_absolute_error
print(mean_absolute_error(y_pred,y_test))
# Out:
# 0.026514285714285737

# %%
from sklearn.metrics import r2_score
print(r2_score(y_pred,y_test))
# Out:
# -1.1891681103323086

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=3)

# %%
x_poly=poly.fit_transform(x)
x_poly
# Out:
# array([[1.00e+00, 1.00e+00, 0.00e+00, 1.00e+00, 0.00e+00, 0.00e+00,
#         1.00e+00, 0.00e+00, 0.00e+00, 0.00e+00],
#        [1.00e+00, 2.00e+00, 2.00e+01, 4.00e+00, 4.00e+01, 4.00e+02,
#         8.00e+00, 8.00e+01, 8.00e+02, 8.00e+03],
#        [1.00e+00, 3.00e+00, 4.00e+01, 9.00e+00, 1.20e+02, 1.60e+03,
#         2.70e+01, 3.60e+02, 4.80e+03, 6.40e+04],
#        [1.00e+00, 4.00e+00, 6.00e+01, 1.60e+01, 2.40e+02, 3.60e+03,
#         6.40e+01, 9.60e+02, 1.44e+04, 2.16e+05],
#        [1.00e+00, 5.00e+00, 8.00e+01, 2.50e+01, 4.00e+02, 6.40e+03,
#         1.25e+02, 2.00e+03, 3.20e+04, 5.12e+05],
#        [1.00e+00, 6.00e+00, 1.00e+02, 3.60e+01, 6.00e+02, 1.00e+04,
#         2.16e+02, 3.60e+03, 6.00e+04, 1.00e+06]])

# %%
poly.fit(x_poly,y)
# Out:
# PolynomialFeatures(degree=3)

# %%
model1=LinearRegression()

# %%
model1.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
y_poly=model1.predict(x_poly)

# %%
y_poly
# Out:
# array([-0.00198889,  0.00724444,  0.00371111,  0.02248889,  0.09865556,
#         0.26728889])

# %%
from sklearn.metrics import accuracy_score

# Assuming y_pred and y_test are your predicted and true labels
y_pred = model.predict(x_test)  # Replace with your actual prediction code

# Convert to integers if needed
y_pred = y_pred.astype(int)
y_test = y_test.astype(int)

# Calculate accuracy
score = accuracy_score(y_pred, y_test)
print(f"Accuracy: {score}")
# Out:
# Accuracy: 1.0
